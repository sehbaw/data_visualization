# %% [markdown]
# <a href="https://colab.research.google.com/github/sehbaw/data_visualization/blob/main/poverty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn.objects as so

# %%
df = pd.read_csv("/poverty.csv",index_col=False)
df.head()
# Out:
#   Unnamed: 0 Bangladesh - poverty headcount ratio at $1.90 a day (2011 PPP)  \
# 0       year                                    % of population
# 1       1991                                                 44
# 2       2016                                                 15
#
#    Unnamed: 2                                         Unnamed: 3
# 0      source                                                URL
# 1  World Bank  https://data.worldbank.org/indicator/SI.POV.DD...
# 2  World Bank  https://data.worldbank.org/indicator/SI.POV.DD...

# %%
header_list = ['year', 'population' , 'source', 'url']

df.to_csv("/poverty1.csv", header=header_list, index=False)

df2 = pd.read_csv("/poverty1.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df2 = df2.drop(index=0)

# %%
df2.head()
# Out:
#    year population      source  \
# 1  1991         44  World Bank
# 2  2016         15  World Bank
#
#                                                  url
# 1  https://data.worldbank.org/indicator/SI.POV.DD...
# 2  https://data.worldbank.org/indicator/SI.POV.DD...

# %%
so.Plot(df2, x='year', color="population").add(so.Bar(), so.Count(), so.Stack())
